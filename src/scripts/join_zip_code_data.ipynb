# %% [markdown]
# ## Join Zip Code Data

# %%
import pandas as pd

# %%
# Load the data sets
us_zips = pd.read_csv("../../data/raw/data/us-zips/uszips.csv")

# %%
us_zips.describe()
# Out:
#                 zip           lat           lng  parent_zcta     population  \
# count  33782.000000  33782.000000  33782.000000          0.0   33763.000000
# mean   49704.961577     38.800991    -90.955683          NaN    9938.457068
# std    27558.568567      5.387881     15.666047          NaN   14964.842941
# min      601.000000    -14.219840   -176.629620          NaN       0.000000
# 25%    26723.000000     35.363265    -97.225690          NaN     645.000000
# 50%    49725.500000     39.476165    -88.184265          NaN    2659.000000
# 75%    72169.750000     42.103912    -80.237623          NaN   13401.000000
# max    99929.000000     71.274340    145.753490          NaN  137213.000000
#
#             density   county_fips
# count  33763.000000  33782.000000
# mean     509.547383  29989.370464
# std     1943.820536  15505.403169
# min        0.000000   1001.000000
# 25%        7.300000  18057.000000
# 50%       30.700000  30029.000000
# 75%      269.950000  42055.000000
# ...
